# %%
# install.packages("rtweet")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(rtweet)

## access token method: create token and save it as an environment variable
create_token(
  app = "urbangeek_dicLab",
  consumer_key = "jePj0MDsQYiWsfOl5KMYrylM3",
  consumer_secret = "ZuL9m5BdiJ6WRgELSmszhhWxPwwGQqWlm5kVrVDSWw5vEowp4z",
  access_token = "28061753-G37g4cKH2eYxI94sTKmJWTE3ZJwUD5C87jgWAF4zu",
  access_secret = "7m5XdVQCk3520zGPr5NfMDu1l5baCW5JfTDQdFJSlfdXR")
# Out:
# <Token>
# <oauth_endpoint>
#  request:   https://api.twitter.com/oauth/request_token
#  authorize: https://api.twitter.com/oauth/authenticate
#  access:    https://api.twitter.com/oauth/access_token
# <oauth_app> urbangeek_dicLab
#   key:    jePj0MDsQYiWsfOl5KMYrylM3
#   secret: <hidden>
# <credentials> oauth_token, oauth_token_secret
# ---

# %%
## search for 10,000 tweets sent from the US


# q <- '\"got fever\" OR \"got a fever\" OR \"have fever\" OR \"have a fever\" OR \"caught fever\" 
# OR \"caught a fever\" OR \"had fever\" OR \"had a fever\" OR \"has a fever\" OR \"down with a fever\"'


# q <- '\"down with fever\" OR \"got cold\" OR \"got a cold\" OR \"have cold\" OR \"have a cold\" 
# OR \"caught cold\" OR \"caught a cold\" OR \"had cold\" OR \"had a cold\" OR \"got flu\" 
# OR \"have flu\" OR \"caught flu\"'



# q <- "\"feverish\" OR \"running a fever\" OR \"running a high fever\" OR \"running a temperature\" 
# OR \"have a temperature\" OR \"got a temperature\" OR \"suffering from fever\" 
# OR \"fever broke\" OR \"viral fever\""

# q <- '"suffering from flu" OR "with the flu" OR "battling the flu" OR "suffering from flu" OR "hate the flu" 
# OR "stomach flu" OR "got the flu" OR "with flu" OR "had the flu"'

q<- '"caught the flu" OR "with flu" OR "had the flu"'

rt <- search_tweets(
    q, 
    n = 15000,
    geocode = "39.8,-95.583068847656,2408km",  
    retryonratelimit = TRUE,
    lang = "en",
    include_rts = FALSE
)

## create lat/lng variables using all available tweet and profile geo-location data
rt <- lat_lng(rt)

# rt
# Out:
# Searching for tweets...
# This may take a few seconds...
# Finished collecting tweets!
# Searching for tweets...
# This may take a few seconds...
# Finished collecting tweets!

# %%
save_as_csv(rt, "data_files/7.csv", prepend_ids = TRUE, na = "",fileEncoding = "UTF-8")

# %%
nrow(rt)
# Out:
# [1] 1417

# %%
rt
# Out:
#      user_id             status_id           created_at
# 1    229560233           1102133312049553409 2019-03-03 09:07:12
# 2    303654302           1102119065269739520 2019-03-03 08:10:36
# 3    22679570            1102118072545132545 2019-03-03 08:06:39
# 4    17962037            1102086647548727296 2019-03-03 06:01:47
# 5    2233753886          1102078840942153728 2019-03-03 05:30:45
# 6    973169984221470720  1102076445248102400 2019-03-03 05:21:14
# 7    1007046603453104133 1102076165404196864 2019-03-03 05:20:08
# 8    419630884           1102076001373351937 2019-03-03 05:19:28
# 9    2927229146          1102073944432168960 2019-03-03 05:11:18
# 1415 27054408            1098579044109611008 2019-02-21 13:43:49
# 1416 1079455199478116358 1098570050401984514 2019-02-21 13:08:05
# 1417 1079455199478116358 1098570050401984514 2019-02-21 13:08:05
#      screen_name
# 1    SMII_Much
# 2    _ImBreaaa
# 3    handmolo
# 4    MrsGrumpy4
# 5    richard_embree
# 6    IdreesCrawley
# 7    ghouleigh
# 8    wackpanther89
# 9    TazedanConfused
# 10   1thouwildfunky
# 11   quinntographer
# 12   DrJCTally
# 13   ohheykels
# 14   mariabamfoo
# 15   real_rich_K
# 16   MMA_FORTE
# 17   LynnyontheFly
# 18   sara_michellle
# 19   kenzijordannn
# 20   oh_freckless
# 21   McNarnia
# 22   AngelaD1969
# 23   kurrennn
# 24   macbarb0503
# 25   AngelaKorras
# 26   AbyssHunted
# 27   LindaCote06
# 28   sharonleighmama
# 29   proudamericanmm
# 30   StinchcombChris
# ⋮    ⋮
# 1388 Kiki_Janae
# 1389 mollieefay
# 1390 evela_news
# 1391 MagalyCova
# 1392 HEYitsMK
# 1393 xosmilemas_
# 1394 shynastybruh
# 1395 benet_xoxo
# 1396 FMHS_Nurse
# 1397 HolyReyes
# 1398 billy2kid45
# 1399 cizzers
# 1400 thejakester1123
# 1401 EarlVOLS19
# 1402 dvdinfatuation
# 1403 MET13579
# 1404 JaclynHimmer
# 1405 stephrunstrack
# 1406 BeatlesFan760
# 1407 VinceBednarik
# 1408 ThatOtherAlcala
# 1409 CZorcov
# 1410 MSN0W3
# 1411 cheekibeats
# 1412 LaterDays33
# 1413 melizabethb7
# 1414 dallasfit
# 1415 Kaliher
# 1416 ColeSny64027586
# 1417 ColeSny64027586
#      text
# 1    I’ve had the flu for the last 4 days and have been absolutely miserable... \U0001f629
# 2    So I was in the store next to this woman today &amp; she’s talking to a lady &amp; goes “yeah, I’ve had the flu since yesterday” like excuse me, since yesterday? Why are you out? Contaminating the world???
# 3    @brianmlucey I am sorry you have no idea what I am saying. AGAIN I will say that I agree with current vaccines, however where do we let governtment stop?\n\nWould you trust Trump if he added a few more vaccines for your kids? Called them the Trump Trio and would help your kids with flu
# 4    @SillyBleep @EvelDick I am working on it. Thought I had the flu. Obviously not. \U0001f642On the positive, a scan I had caught a tumor as well, so I can only go up from here.
# 5    @andy56823369 @ufc @lionheartasmith Yeah there’s been some weird ones tonight. Woodley literally looked like he had the flu or something. End of round one he was POURING sweat like he’d been in a 4 round war already.
# 6    Someone said a few days back that Woodley had the flu or something. Not sure if it was a joke or not, but he did not look like himself at all. Congrats to the new champ!!! What a statement win. #UFC235 #AfricanMMA #ATourIsComing
# 7    @VanBiztheRapper Same! Like, I drank a little when I had the flu but I had such a bad fever I just laid there and went to sleep. I’m so in the party zone right now and I’m totally alone so it’s weird lol I’m just jamming to music basically. Work was so bad, I totally deserve it lol
# 8    @thatfleenorguy Like he had the flu or some shit
# 9    Props to Usman for implementing his gameplan, but Woodley looked like he had the flu or something... Literally looked like fighting was the last thing he wanted to do today.\n\n#UFC235
fluTweet <- read.csv(file="combine.csv", header=TRUE, sep=",")
nrow(fluTweet)

fluTweet <- fluTweet[!(is.na(fluTweet$lat) | fluTweet$lat==""), ]
nrow(fluTweet)

fluTweet <- unique(fluTweet, by = "status_id")
nrow(fluTweet)
fluTweet
# Out:
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/geo+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vdom.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.plotly.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vegalite.v2+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vega.v4+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# [1] 12694
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/geo+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vdom.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.plotly.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vegalite.v2+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vega.v4+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# [1] 1477
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/geo+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vdom.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.plotly.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vegalite.v2+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vega.v4+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# [1] 1468
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/geo+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vdom.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.plotly.v1+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vegalite.v2+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
# ERROR while rich displaying an object: Error in withCallingHandlers({: No repr_* for mimetype application/vnd.vega.v4+json in repr::mime2repr
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#       user_id              status_id            created_at
# 14    x3128871242          x1102074500684890112 2019-03-03 05:13:31
# 22    x19264828            x1102061224328458240 2019-03-03 04:20:45
# 24    x1015002107676676096 x1102056548552056832 2019-03-03 04:02:11
# 28    x748540776           x1102049387801440257 2019-03-03 03:33:43
# 29    x195530482           x1102047598553182208 2019-03-03 03:26:37
# 33    x72694192            x1102044151745413121 2019-03-03 03:12:55
# 50    x2723857468          x1102006806400913408 2019-03-03 00:44:31
# 71    x811035538081873921  x1101952182985863173 2019-03-02 21:07:28
# 85    x1102562826          x1101932781981102081 2019-03-02 19:50:22
# 93    x3306659422          x1101910104566308865 2019-03-02 18:20:16
# 103   x1488331856          x1101881842024747008 2019-03-02 16:27:57
# 104   x366882779           x1101880550061674497 2019-03-02 16:22:49
# 116   x3776623994          x1101859499097255938 2019-03-02 14:59:10
# 122   x2868302478          x1101836758793113601 2019-03-02 13:28:49
# 139   x26144652            x1099742510044217344 2019-02-24 18:47:01
# 140   x26144652            x1101751021922062337 2019-03-02 07:48:07
# 146   x2924009909          x1101703835901460480 2019-03-02 04:40:37
# 147   x837780081472786432  x1101696532968022016 2019-03-02 04:11:36
# 150   x255655088           x1101690926278365184 2019-03-02 03:49:19
# 151   x41300397            x1101682178339946496 2019-03-02 03:14:34
# 155   x46280725            x1101672717881733120 2019-03-02 02:36:58
# 160   x289572264           x1101660551267135488 2019-03-02 01:48:37
# 164   x2505895861          x1101654202630238208 2019-03-02 01:23:24
# 174   x175122652           x1101642836502556679 2019-03-02 00:38:14
# 178   x701826555559829504  x1101637595983998977 2019-03-02 00:17:24
# 180   x265637778           x1101633103557283845 2019-03-01 23:59:33
# 193   x96450411            x1101616864768204802 2019-03-01 22:55:02
# 194   x2897361447          x1101615500935786498 2019-03-01 22:49:37
# 204   x285930209           x1101593394680344582 2019-03-01 21:21:46
# 222   x437954836           x1101561327548489728 2019-03-01 19:14:21
# ⋮     ⋮                    ⋮                    ⋮
# 12352 x32334213            x1099392055543947264 2019-02-23 19:34:26
# 12356 x81927707            x1099386603565387782 2019-02-23 19:12:46
# 12564 https://pbs.twimg.com/profile_banners/242139106/1549355749
# 12565 https://pbs.twimg.com/profile_banners/861632814470639617/1550213522
# 12569
# 12585 https://pbs.twimg.com/profile_banners/2514482348/1542333914
# 12607 https://pbs.twimg.com/profile_banners/4709677436/1511691496
# 12635 https://pbs.twimg.com/profile_banners/1092150026699239426/1551034102
# 12644 https://pbs.twimg.com/profile_banners/23131905/1487579182
# 12671
# 12678 https://pbs.twimg.com/profile_banners/35236677/1550519358
# 12680 https://pbs.twimg.com/profile_banners/17140002/1533177156
# 12690 https://pbs.twimg.com/profile_banners/17656530/1457312548
#       profile_background_url
# 14    http://abs.twimg.com/images/themes/theme1/bg.png
# 22    http://abs.twimg.com/images/themes/theme7/bg.gif
# 24
# 28    http://abs.twimg.com/images/themes/theme9/bg.gif
# 29    http://abs.twimg.com/images/themes/theme1/bg.png
# 33    http://abs.twimg.com/images/themes/theme1/bg.png
# 50    http://abs.twimg.com/images/themes/theme1/bg.png
# 71    http://abs.twimg.com/images/themes/theme1/bg.png
# 85    http://abs.twimg.com/images/themes/theme1/bg.png
# 93    http://abs.twimg.com/images/themes/theme1/bg.png
# 103   http://abs.twimg.com/images/themes/theme18/bg.gif
# 104   http://abs.twimg.com/images/themes/theme1/bg.png
# 116   http://abs.twimg.com/images/themes/theme1/bg.png
# 122   http://abs.twimg.com/images/themes/theme1/bg.png
# 139   http://abs.twimg.com/images/themes/theme9/bg.gif
# 140   http://abs.twimg.com/images/themes/theme9/bg.gif
# 146   http://abs.twimg.com/images/themes/theme1/bg.png
# 147
# 150   http://abs.twimg.com/images/themes/theme1/bg.png
# 151   http://abs.twimg.com/images/themes/theme14/bg.gif
# 155   http://abs.twimg.com/images/themes/theme12/bg.gif
# 160   http://abs.twimg.com/images/themes/theme1/bg.png
# 164   http://abs.twimg.com/images/themes/theme1/bg.png
# 174   http://abs.twimg.com/images/themes/theme1/bg.png
# 178
# 180   http://abs.twimg.com/images/themes/theme2/bg.gif
# 193   http://abs.twimg.com/images/themes/theme14/bg.gif
# 194   http://abs.twimg.com/images/themes/theme1/bg.png
# 204   http://abs.twimg.com/images/themes/theme3/bg.gif
# 222   http://abs.twimg.com/images/themes/theme1/bg.png
# ⋮     ⋮
# 12352 http://abs.twimg.com/images/themes/theme19/bg.gif
# 12356 http://abs.twimg.com/images/themes/theme1/bg.png
# 12357
# 12401 http://abs.twimg.com/images/themes/theme1/bg.png
# 12407 http://abs.twimg.com/images/themes/theme3/bg.gif
# 12409 http://abs.twimg.com/images/themes/theme1/bg.png
# 12444
# 12447
# 12461 http://abs.twimg.com/images/themes/theme1/bg.png
# 12472 http://abs.twimg.com/images/themes/theme1/bg.png
# 12475 http://abs.twimg.com/images/themes/theme1/bg.png
# 12480
# 12490 http://abs.twimg.com/images/themes/theme9/bg.gif
# 12503 http://abs.twimg.com/images/themes/theme1/bg.png
# 12518 http://abs.twimg.com/images/themes/theme1/bg.png
# 12541 http://abs.twimg.com/images/themes/theme1/bg.png
# 12680 http://pbs.twimg.com/profile_images/1090815120001912833/KU7gsWUh_normal.jpg
# 12690 http://pbs.twimg.com/profile_images/1066564937286221824/6EqO0zrL_normal.jpg
#       lat      lng
# 14    39.95178  -83.13282
# 22    37.90855 -122.27735
# 24    41.83358  -87.73201
# 28    40.00487  -75.11800
# 29    47.46506 -122.34728
# 33    40.56419 -105.06394
# 50    35.84398  -78.65784
# 71    42.53328  -71.10361
# 85    40.34554  -94.86335
# 93    41.51667  -81.66667
# 103   39.99468  -82.98577
# 104   40.78071  -73.96854
# 116   37.71553 -121.91453
# 122   36.83080 -119.63619
# 139   38.30456  -92.43677
# 140   38.30456  -92.43677
# 146   36.89508  -76.25569
# 147   38.00338  -79.42087
# 150   31.16889 -100.07689
# 151   41.55830  -73.03690
# 155   40.68865  -73.93865
# 160   39.84446  -74.18328
# 164   35.83052  -85.97860
# 174   38.74317  -90.11198
# 178   34.75194  -92.13127
# 180   40.19490  -74.04830
# 193   33.76719  -84.43311
# 194   33.63114  -80.92663
# 204   35.84398  -78.65784
# 222   33.82508 -116.51729
# ⋮     ⋮        ⋮
# 12352 34.02079 -118.41191
# 12356 42.03694  -71.68350
# 12357 43.05972  -89.32971
# 12401 33.97934 -117.58004
# 12407 37.79199 -122.22869
# 12409 33.39288 -111.92814
# 12444 47.27302 -120.88248
# 12447 41.11794  -77.60468
# 12461 31.16889 -100.07689
# 12472 41.27572  -96.05343
# 12475 37.05090  -76.36228
# 12480 40.78071  -73.96854
# 12490 38.80511  -77.23697
# 12503 42.48428  -83.37718
# 12518 34.13493 -117.29410
# 12541 38.89860  -77.01440
# 12546 38.80511  -77.23697
# 12547 38.19555  -85.72235
# 12555 35.34690 -119.02516
# 12564 33.93805 -118.19403
# 12565 43.41819  -79.64508
# 12569 27.99659  -82.44269
# 12585 30.32335  -97.75472
# 12607 33.39288 -111.92814
# 12635 39.89929 -105.06835
# 12644 39.99468  -82.98577
# 12671 35.64470 -109.09500
# 12678 36.16750 -115.14900
# 12680 36.10939  -95.91364
# 12690 47.61482 -122.33060

# %%
## plot state boundaries
par(mar = c(0, 0, 0, 0))
maps::map("state", lwd = .25)

## plot lat and lng points onto state map
with(fluTweet, points(lng, lat, pch = 20, cex = .75, col = rgb(0, .3, .7, .75)))
# Out:
# plot without title

# %%
library(maps)
library(maptools)
library(sp)
library(plyr)

testPoints <- data.frame(x = fluTweet$lng, y = fluTweet$lat)
states <- map('state', fill=TRUE, col="transparent", plot=FALSE)

IDs <- sapply(strsplit(states$names, ":"), function(x) x[1])
states_sp <- map2SpatialPolygons(states, IDs=IDs,
                     proj4string=CRS("+proj=longlat +datum=WGS84"))
              
pointsSP <- SpatialPoints(testPoints, 
                    proj4string=CRS("+proj=longlat +datum=WGS84"))
   
indices <- over(pointsSP, states_sp)

stateNames <- sapply(states_sp@polygons, function(x) x@ID)
fluTweet$state <- stateNames[indices]
fluTweet <- fluTweet[!(is.na(fluTweet$state) | fluTweet$state==""), ]
